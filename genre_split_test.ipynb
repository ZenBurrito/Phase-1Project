# %% [markdown]
# ### Data cleaning:  IMDB- title.crew
# The following codes merges director names in imdb.name.basics and director ids in imdb.title.crew
#
# Name of clean datasets:
# "df_directors_wide" and "df_directors_long"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Step 1: Clearning imdb.title.crew

# %%
# Read original data
df_title_crew = pd.read_csv('Data/zippedData/imdb.title.crew.csv.gz')
df_title_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
df_title_crew.sample(5)
# Out:
#           tconst  directors    writers
# 54839  tt2300970  nm4055874  nm4055874
# 74191  tt7317422  nm6003515  nm6003515
# 3532   tt7379594  nm0296638  nm2313551
# 4547   tt2507224  nm5409175  nm5409175
# 5040   tt3916754  nm2284321        NaN

# %%
# Make a copy of the original dataset
df_crew= df_title_crew.copy()

# Delete 'writers' 
df_crew.drop(['writers'], axis=1, inplace=True)

# Drop missing values in 'directors'
df_crew.dropna(axis=0, subset=['directors'], inplace=True)

# Drop duplicate in 'tconst', film id
df_crew.drop_duplicates(subset='tconst', inplace=True)

df_crew.head()
# Out:
#       tconst                      directors
# 0  tt0285252                      nm0899854
# 2  tt0462036                      nm1940585
# 3  tt0835418                      nm0151540
# 4  tt0878654  nm0089502,nm2291498,nm2292011
# 5  tt0879859                      nm2416460

# %%
# Count how many directors in each cell. 

# Create a new data frame with split directors columns 
directors = df_crew['directors'].str.split(',', expand =True)
 
directors.info()

# Most films has only one or two directors. 
# For this project, drop films with 4 or more directors
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140417 entries, 0 to 146142
# Data columns (total 83 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       140417 non-null  object
#  1   1       15727 non-null   object
#  2   2       2501 non-null    object
#  3   3       1090 non-null    object
#  4   4       710 non-null     object
#  5   5       517 non-null     object
#  6   6       401 non-null     object
#  7   7       321 non-null     object
#  8   8       258 non-null     object
#  9   9       206 non-null     object
#  10  10      139 non-null     object
#  11  11      112 non-null     object
#  12  12      92 non-null      object
#  13  13      77 non-null      object
#  14  14      69 non-null      object
#  15  15      65 non-null      object
#  16  16      60 non-null      object
#  17  17      58 non-null      object
#  18  18      53 non-null      object
#  19  19      50 non-null      object
#  20  20      43 non-null      object
#  21  21      39 non-null      object
#  22  22      37 non-null      object
#  23  23      35 non-null      object
#  24  24      33 non-null      object
#  25  25      32 non-null      object
#  26  26      28 non-null      object
#  27  27      26 non-null      object
#  28  28      24 non-null      object
#  29  29      22 non-null      object
#  30  30      20 non-null      object
#  31  31      16 non-null      object
#  32  32      14 non-null      object
#  33  33      13 non-null      object
#  34  34      11 non-null      object
#  35  35      11 non-null      object
#  36  36      11 non-null      object
#  37  37      11 non-null      object
#  38  38      11 non-null      object
#  39  39      10 non-null      object
#  40  40      9 non-null       object
#  41  41      8 non-null       object
#  42  42      8 non-null       object
#  43  43      8 non-null       object
#  44  44      8 non-null       object
#  45  45      8 non-null       object
#  46  46      7 non-null       object
#  47  47      7 non-null       object
#  48  48      6 non-null       object
#  49  49      6 non-null       object
#  50  50      6 non-null       object
#  51  51      5 non-null       object
#  52  52      5 non-null       object
#  53  53      5 non-null       object
#  54  54      5 non-null       object
#  55  55      5 non-null       object
#  56  56      5 non-null       object
#  57  57      5 non-null       object
#  58  58      5 non-null       object
#  59  59      4 non-null       object
#  60  60      4 non-null       object
#  61  61      3 non-null       object
#  62  62      3 non-null       object
#  63  63      2 non-null       object
#  64  64      2 non-null       object
#  65  65      2 non-null       object
#  66  66      2 non-null       object
#  67  67      2 non-null       object
#  68  68      2 non-null       object
#  69  69      2 non-null       object
#  70  70      2 non-null       object
#  71  71      2 non-null       object
#  72  72      2 non-null       object
#  73  73      1 non-null       object
#  74  74      1 non-null       object
#  75  75      1 non-null       object
#  76  76      1 non-null       object
#  77  77      1 non-null       object
#  78  78      1 non-null       object
#  79  79      1 non-null       object
#  80  80      1 non-null       object
#  81  81      1 non-null       object
#  82  82      1 non-null       object
# dtypes: object(83)
# memory usage: 90.0+ MB

# %%
# Drop films with 4 or more directors 

# Step 1 - split directors into director1, director2, director3, director4 
# 'director4' has 4th and above directors
df_crew[['director1', 'director2', 'director3', 'director4']] = df_crew['directors'].str.split(',', n=3,  expand =True)

# Step 2 - drop rows which 'director4' is not null.
df_crew.dropna(axis=0, subset=['director4'])

# Step 3 - drop 'directors' and 'director4' columns. 
df_crew.drop(['directors', 'director4'], axis=1, inplace=True)

df_crew.sample(20)
# Out:
#            tconst   director1  director2  director3
# 2312    tt2009513   nm4007409       None       None
# 474     tt2168380   nm5070515  nm5070638       None
# 110560  tt5599880   nm6513041       None       None
# 43996   tt8435932   nm1818028       None       None
# 48517   tt5588666   nm6590346       None       None
# 11261   tt2254068   nm2551464       None       None
# 35884   tt6401220   nm1511400       None       None
# 108927  tt1890484   nm4414819       None       None
# 46439   tt4493074   nm4901385       None       None
# 73970   tt6023498   nm5354456       None       None
# 25033   tt3732926   nm6402132       None       None
# 64640   tt9252282  nm10246382       None       None
# 117804  tt4475126   nm5810182       None       None
# 47175   tt1612142   nm0150916  nm0150929       None
# 144760  tt3442788   nm0290485  nm6192356  nm4201336
# 65827   tt4104202   nm1984645       None       None
# 142212  tt4241904   nm0371642       None       None
# 133096  tt9564712  nm10327897       None       None
# 91910   tt1430131   nm2576051       None       None
# 23975   tt9010246   nm6381109       None       None

# %% [markdown]
# ### Step 2: Clearning imdb.name.basics

# %%
df_name = pd.read_csv('Data/zippedData/imdb.name.basics.csv.gz')
df_name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
df_name.sample(5)
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 466169  nm5346535       Daniel Bilenko         NaN         NaN
# 192535  nm4262803   Laurence Roothooft         NaN         NaN
# 124928  nm2892583  Nima Shahrokh Shahi         NaN         NaN
# 338502  nm3092471       Marwan Kenzari      1983.0         NaN
# 521823  nm8745869           Adam White         NaN         NaN
#
#            primary_profession                         known_for_titles
# 466169  actor,writer,producer            tt3966602,tt2484546,tt2280478
# 192535                actress  tt2113766,tt5203748,tt5921264,tt5347122
# 124928                  actor  tt1964988,tt8374200,tt3131744,tt1431278
# 338502                  actor  tt3402236,tt2638144,tt1536537,tt6139732
# 521823                 editor                                tt6480984

# %%
# Keep 'nconst', 'primary_name'
df_name2 = df_name[['nconst', 'primary_name' ]]

df_name2
# Out:
#            nconst         primary_name
# 0       nm0061671    Mary Ellen Bauder
# 1       nm0061865         Joseph Bauer
# 2       nm0062070           Bruce Baum
# 3       nm0062195         Axel Baumann
# 4       nm0062798          Pete Baxter
# ...           ...                  ...
# 606643  nm9990381         Susan Grobes
# 606644  nm9990690          Joo Yeon So
# 606645  nm9991320       Madeline Smith
# 606646  nm9991786  Michelle Modigliani
# 606647  nm9993380       Pegasus Envoyé
#
# [606648 rows x 2 columns]

# %% [markdown]
# ### Step 3: Merge director ids (in df_crew) and director names (in df_name2)

# %%
# Merge names of directors for director1, and rename it director_name1  

df_merge1 = df_crew.merge(df_name2, how='left', left_on='director1', right_on='nconst' )

# Rename
df_merge1.rename(columns={'primary_name':'director_name1'}, inplace=True)

# drop keys
df_merge1.drop(axis=1, columns='nconst', inplace=True)

df_merge1.head(2)
# Out:
#       tconst  director1 director2 director3 director_name1
# 0  tt0285252  nm0899854      None      None    Tony Vitale
# 1  tt0462036  nm1940585      None      None     Bill Haley

# %%
# Merge names of directors for director2, and rename it director_name2  
df_merge2 = df_merge1.merge(df_name2, how='left', left_on='director2', right_on='nconst' )

# Rename
df_merge2.rename(columns={'primary_name':'director_name2'}, inplace=True)

# drop keys
df_merge2.drop(axis=1, columns='nconst', inplace=True)

df_merge2.head(2)
# Out:
#       tconst  director1 director2 director3 director_name1 director_name2
# 0  tt0285252  nm0899854      None      None    Tony Vitale            NaN
# 1  tt0462036  nm1940585      None      None     Bill Haley            NaN

# %%
# Merge names of directors for director3, and rename it director_name3

df_merge3 = df_merge2.merge(df_name2, how='left', left_on='director2', right_on='nconst' )

# Rename
df_merge3.rename(columns={'primary_name':'director_name3'}, inplace=True)

# drop keys
df_merge3.drop(axis=1, columns='nconst', inplace=True)

df_merge3.head(2)
# Out:
#       tconst  director1 director2 director3 director_name1 director_name2  \
# 0  tt0285252  nm0899854      None      None    Tony Vitale            NaN
# 1  tt0462036  nm1940585      None      None     Bill Haley            NaN
#
#   director_name3
# 0            NaN
# 1            NaN

# %% [markdown]
# ### Clean dataset in a wide format

# %%
df_directors_wide = df_merge3
df_directors_wide.head(3)
# Out:
#       tconst  director1 director2 director3     director_name1 director_name2  \
# 0  tt0285252  nm0899854      None      None        Tony Vitale            NaN
# 1  tt0462036  nm1940585      None      None         Bill Haley            NaN
# 2  tt0835418  nm0151540      None      None  Jay Chandrasekhar            NaN
#
#   director_name3
# 0            NaN
# 1            NaN
# 2            NaN

# %% [markdown]
# ### Reshape from wide to long format

# %%
## reshape wide to long format 
df_directors_long = pd.wide_to_long(df_directors_wide, ["director", "director_name"], i='tconst', j='n_th_director' )


# Drop NaN in 'director'
df_directors_long.dropna(axis=0, subset=['director'], inplace=True)

df_directors_long.reset_index(inplace=True)

# Delete 'n_th_director' 

df_directors_long.drop('n_th_director', axis=1, inplace=True)

# %% [markdown]
# ### Clean dataset in a long format

# %%
df_directors_long.head()
# Out:
#       tconst   director      director_name
# 0  tt0285252  nm0899854        Tony Vitale
# 1  tt0462036  nm1940585         Bill Haley
# 2  tt0835418  nm0151540  Jay Chandrasekhar
# 3  tt0878654  nm0089502        Albert Pyun
# 4  tt0879859  nm2416460    Eric Manchester

# %%
#number of films shot by directors 

df_directors_long['director_name'].value_counts()[:20]
# Out:
# Omer Pasha             62
# Larry Rosen            51
# Rajiv Chilaka          50
# Stephan Düfel          48
# Graeme Duane           45
# Gérard Courant         44
# Claudio Costa          42
# Nayato Fio Nuala       41
# Eckhart Schmidt        37
# Sergey A.              36
# Tetsuya Takehora       33
# Michael Fredianelli    32
# Charlie Minn           30
# Dustin Ferguson        29
# Paul T.T. Easter       28
# William Winckler       27
# Philip Gardiner        27
# Yoshikazu Katô         27
# Manny Velazquez        27
# Ram Gopal Varma        26
# Name: director_name, dtype: int64

# %% [markdown]
# ### Merging mdb.title.ratings

# %%
df_title_rating = pd.read_csv('Data/zippedData/imdb.title.ratings.csv.gz')
df_title_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
# drop 'numvotes'
df_title_rating.drop(axis=1, columns = 'numvotes', inplace=True)

# %%
# Merge imdb.title.ratings and emiko's df_directors_wide 

df_directors_ratings = df_title_rating.merge(df_directors_wide, how='inner', on='tconst' )

# %%
df_directors_ratings.head(3)
# Out:
#        tconst  averagerating  director1  director2 director3  \
# 0  tt10356526            8.3  nm8353804       None      None
# 1  tt10384606            8.9  nm9932562  nm9250842      None
# 2   tt1042974            6.4  nm1915232       None      None
#
#          director_name1    director_name2    director_name3
# 0         Sukh Sanghera               NaN               NaN
# 1  George Llewelyn-John  Caolan Robertson  Caolan Robertson
# 2          Marcel Grant               NaN               NaN

# %% [markdown]
# ### Merge Piotr data to df_directors_ratings

# %%
df_title_basic = pd.read_csv('Data/zippedData/imdb.title.basics.csv.gz')
df_title_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df_title_basic
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
df_title_basic.dropna(inplace = True)

# %%
df_title_basic
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                      The Rehearsal
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# 0                                               Sunghursh        2013
# 1                                         Ashad Ka Ek Din        2019
# 2                              The Other Side of the Wind        2018
# 4                                   La Telenovela Errante        2017
# 5                                             A Thin Life        2018
# ...                                                   ...         ...
# 146134                                         Drømmeland        2019
# 146135                                           O Ensaio        2019
# 146136  Illenau - die Geschichte einer ehemaligen Heil...        2017
# 146137                                          Safeguard        2019
# 146139                                Kuambil Lagi Hatiku        2019
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 4                  80.0  Comedy,Drama,Fantasy
# 5                  75.0                Comedy
# ...                 ...                   ...
# 146134             72.0           Documentary
# 146135             51.0                 Drama
# 146136             84.0           Documentary
# 146137             90.0        Drama,Thriller
# 146139            123.0                 Drama
#
# [112232 rows x 6 columns]

# %%
df_year = df_title_basic[df_title_basic["start_year"] >= 2010]

# %%
df_year = df_title_basic[df_title_basic["start_year"] <= 2021]

# %%
df_year["start_year"].value_counts()
# Out:
# 2016    13253
# 2017    13240
# 2015    12965
# 2014    12693
# 2013    12070
# 2018    12055
# 2012    11180
# 2011    10462
# 2010     9793
# 2019     4433
# 2020       81
# 2021        4
# Name: start_year, dtype: int64

# %%
df_year.drop("primary_title", axis=1, inplace=True)
# Out:
# C:\Users\danie\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_year
# Out:
#            tconst                                     original_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                                    Ashad Ka Ek Din
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                              La Telenovela Errante
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                           O Ensaio
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#         start_year  runtime_minutes                genres
# 0             2013            175.0    Action,Crime,Drama
# 1             2019            114.0       Biography,Drama
# 2             2018            122.0                 Drama
# 4             2017             80.0  Comedy,Drama,Fantasy
# 5             2018             75.0                Comedy
# ...            ...              ...                   ...
# 146134        2019             72.0           Documentary
# 146135        2019             51.0                 Drama
# 146136        2017             84.0           Documentary
# 146137        2019             90.0        Drama,Thriller
# 146139        2019            123.0                 Drama
#
# [112229 rows x 5 columns]

# %%
# Merge piotr's df_year and emiko's df_directors_wide 

df_imdb = df_year.merge(df_directors_ratings, how='inner', on='tconst' )

# %%
df_imdb.head()
# Out:
#       tconst              original_title  start_year  runtime_minutes  \
# 0  tt0063540                   Sunghursh        2013            175.0
# 1  tt0066787             Ashad Ka Ek Din        2019            114.0
# 2  tt0069049  The Other Side of the Wind        2018            122.0
# 3  tt0100275       La Telenovela Errante        2017             80.0
# 4  tt0137204             Joe Finds Grace        2017             83.0
#
#                        genres  averagerating  director1  director2 director3  \
# 0          Action,Crime,Drama            7.0  nm0712540       None      None
# 1             Biography,Drama            7.2  nm0002411       None      None
# 2                       Drama            6.9  nm0000080       None      None
# 3        Comedy,Drama,Fantasy            6.5  nm0765384  nm0749914      None
# 4  Adventure,Animation,Comedy            8.1  nm0365480       None      None
#
#         director_name1 director_name2 director_name3
# 0  Harnam Singh Rawail            NaN            NaN
# 1            Mani Kaul            NaN            NaN
# 2         Orson Welles            NaN            NaN
# 3    Valeria Sarmiento     Raoul Ruiz     Raoul Ruiz
# 4     Anthony Harrison            NaN            NaN

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65305 entries, 0 to 65304
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           65305 non-null  object
#  1   original_title   65305 non-null  object
#  2   start_year       65305 non-null  int64
#  3   runtime_minutes  65305 non-null  float64
#  4   genres           65305 non-null  object
#  5   averagerating    65305 non-null  float64
#  6   director1        65305 non-null  object
#  7   director2        7256 non-null   object
#  8   director3        1195 non-null   object
#  9   director_name1   65304 non-null  object
#  10  director_name2   7256 non-null   object
#  11  director_name3   7256 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 6.5+ MB

# %%
df_num = pd.read_csv('Data/zippedData/tn.movie_budgets.csv.gz')
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
def data_cleaning_money(column_name):
    df_num[column_name] = df_num[column_name].str.replace('$', '').str.replace(',', '').astype(float)

# %%
data_cleaning_money('production_budget')
data_cleaning_money('domestic_gross')
data_cleaning_money('worldwide_gross')
df_num['release_date'] = pd.to_datetime(df_num['release_date'])
df_num_cleaned = df_num.drop(columns = 'id')

# %%
df_num_good = df_num_cleaned[df_num_cleaned['domestic_gross'] != 0.0]
df_num_good = df_num_good[df_num_good['worldwide_gross'] != 0.0]
df_num_good = df_num_good[df_num_good['production_budget'] != 0.0]
df_num_good = df_num_good[df_num_good['domestic_gross'] != df_num_good['worldwide_gross']]

# %%
df_num_good['ROI'] = (df_num_good['worldwide_gross'] - df_num_good['production_budget']) / df_num_good['production_budget']
df_num_final = df_num_good.sort_values(by = 'ROI', ascending = False)
df_num_final.drop(df_num_final[df_num_final['release_date'] < pd.Timestamp(2010, 1, 1)].index, inplace = True)
df_num_final['profit'] = (df_num_final['worldwide_gross'] - df_num_final['production_budget'])
df_num_final['month'] = df_num_final['release_date'].dt.month

# %%
df_num_final
# Out:
#      release_date                  movie  production_budget  domestic_gross  \
# 5679   2015-07-10            The Gallows           100000.0      22764410.0
# 5211   2012-01-06       The Devil Inside          1000000.0      53262945.0
# 5062   2011-04-01              Insidious          1500000.0      54009150.0
# 5213   2015-04-17             Unfriended          1000000.0      32789645.0
# 4664   2010-10-20  Paranormal Activity 2          3000000.0      84752907.0
# ...           ...                    ...                ...             ...
# 4059   2015-01-30       Trudno byt bogom          7000000.0         31443.0
# 2318   2010-06-30             Love Ranch         25000000.0        137885.0
# 2005   2015-06-05        United Passions         30000000.0           918.0
# 4970   2010-06-11             Jerusalema          2000000.0          7294.0
# 1242   2013-11-01             Mr. Nobody         46500000.0          3622.0
#
#       worldwide_gross         ROI       profit  month
# 5679       41656474.0  415.564740   41556474.0      7
# 5211      101759490.0  100.759490  100759490.0      1
# 5062       99870886.0   65.580591   98370886.0      4
# 5213       64364198.0   63.364198   63364198.0      4
# 4664      177512032.0   58.170677  174512032.0     10
# ...               ...         ...          ...    ...
# 4059          41038.0   -0.994137   -6958962.0      1
# 2318         146149.0   -0.994154  -24853851.0      6
# 2005         168832.0   -0.994372  -29831168.0      6
# 4970          10679.0   -0.994660   -1989321.0      6
# 1242          22254.0   -0.999521  -46477746.0     11
#
# [1622 rows x 8 columns]

# %%
df_merge = df_num_final.merge(df_imdb, how = 'inner', left_on = 'movie', right_on = 'original_title')

# %%
df_merge
# Out:
#      release_date                  movie  production_budget  domestic_gross  \
# 0      2015-07-10            The Gallows           100000.0      22764410.0
# 1      2012-01-06       The Devil Inside          1000000.0      53262945.0
# 2      2011-04-01              Insidious          1500000.0      54009150.0
# 3      2015-04-17             Unfriended          1000000.0      32789645.0
# 4      2010-10-20  Paranormal Activity 2          3000000.0      84752907.0
# ...           ...                    ...                ...             ...
# 1604   2012-11-02                  Vamps         16000000.0          3361.0
# 1605   2012-11-02                  Vamps         16000000.0          3361.0
# 1606   2015-01-30       Trudno byt bogom          7000000.0         31443.0
# 1607   2010-06-30             Love Ranch         25000000.0        137885.0
# 1608   2015-06-05        United Passions         30000000.0           918.0
#
#       worldwide_gross         ROI       profit  month     tconst  \
# 0          41656474.0  415.564740   41556474.0      7  tt2309260
# 1         101759490.0  100.759490  100759490.0      1  tt1560985
# 2          99870886.0   65.580591   98370886.0      4  tt1591095
# 3          64364198.0   63.364198   63364198.0      4  tt3713166
# 4         177512032.0   58.170677  174512032.0     10  tt1536044
# ...               ...         ...          ...    ...        ...
# 1604          94812.0   -0.994074  -15905188.0     11  tt1545106
# 1605          94812.0   -0.994074  -15905188.0     11  tt1719676
# 1606          41038.0   -0.994137   -6958962.0      1  tt2328813
# 1607         146149.0   -0.994154  -24853851.0      6  tt1125929
# 1608         168832.0   -0.994372  -29831168.0      6  tt2814362
#
#              original_title  start_year  runtime_minutes  \
# 0               The Gallows        2015             81.0
# 1          The Devil Inside        2012             83.0
# 2                 Insidious        2010            103.0
# 3                Unfriended        2014             83.0
# 4     Paranormal Activity 2        2010             91.0
# ...                     ...         ...              ...
# 1604                  Vamps        2012             92.0
# 1605                  Vamps        2010             89.0
# 1606       Trudno byt bogom        2013            177.0
# 1607             Love Ranch        2010            117.0
# 1608        United Passions        2014            110.0
#
#                        genres  averagerating  director1  director2 director3  \
# 0     Horror,Mystery,Thriller            4.2  nm4000389  nm3951039      None
# 1                      Horror            4.2  nm0068587       None      None
# 2     Horror,Mystery,Thriller            6.9  nm1490123       None      None
# 3     Horror,Mystery,Thriller            5.6  nm0300174       None      None
# 4                      Horror            5.7  nm0931095       None      None
# ...                       ...            ...        ...        ...       ...
# 1604    Comedy,Horror,Romance            5.2  nm0002132       None      None
# 1605   Comedy,Horror,Thriller            4.5  nm1209639       None      None
# 1606             Drama,Sci-Fi            6.7  nm0314516       None      None
# 1607   Biography,Comedy,Drama            5.6  nm0000431       None      None
# 1608      Drama,History,Sport            2.1  nm0041474       None      None
#
#           director_name1 director_name2 director_name3
# 0           Travis Cluff   Chris Lofing   Chris Lofing
# 1     William Brent Bell            NaN            NaN
# 2              James Wan            NaN            NaN
# 3        Levan Gabriadze            NaN            NaN
# 4           Tod Williams            NaN            NaN
# ...                  ...            ...            ...
# 1604      Amy Heckerling            NaN            NaN
# 1605       Marcus Dreeke            NaN            NaN
# 1606      Aleksey German            NaN            NaN
# 1607     Taylor Hackford            NaN            NaN
# 1608   Frédéric Auburtin            NaN            NaN
#
# [1609 rows x 20 columns]

# %%
df_merge.drop('original_title', axis = 1, inplace = True)

# %%
df_dubplicates = df_merge[df_merge.duplicated('movie')]

# %%
df_dubplicates
# Out:
#      release_date          movie  production_budget  domestic_gross  \
# 6      2017-01-20          Split          5000000.0     138141585.0
# 7      2017-01-20          Split          5000000.0     138141585.0
# 8      2017-01-20          Split          5000000.0     138141585.0
# 9      2017-01-20          Split          5000000.0     138141585.0
# 24     2018-04-13  Truth or Dare          3500000.0      41411015.0
# ...           ...            ...                ...             ...
# 1584   2011-09-16              3          7200000.0         59774.0
# 1585   2011-09-16              3          7200000.0         59774.0
# 1586   2011-09-16              3          7200000.0         59774.0
# 1593   2014-12-26       Barbecue         10000000.0           388.0
# 1605   2012-11-02          Vamps         16000000.0          3361.0
#
#       worldwide_gross        ROI       profit  month     tconst  start_year  \
# 6         278964806.0  54.792961  273964806.0      1  tt3315656        2016
# 7         278964806.0  54.792961  273964806.0      1  tt4972582        2016
# 8         278964806.0  54.792961  273964806.0      1  tt5495666        2016
# 9         278964806.0  54.792961  273964806.0      1  tt6147768        2016
# 24         95127344.0  26.179241   91627344.0      4  tt2125681        2013
# ...               ...        ...          ...    ...        ...         ...
# 1584         295492.0  -0.958959   -6904508.0      9  tt2123129        2012
# 1585         295492.0  -0.958959   -6904508.0      9  tt2379653        2012
# 1586         295492.0  -0.958959   -6904508.0      9  tt5618160        2018
# 1593         247565.0  -0.975244   -9752435.0     12  tt6090268        2017
# 1605          94812.0  -0.994074  -15905188.0     11  tt1719676        2010
#
#       runtime_minutes                   genres  averagerating  director1  \
# 6               127.0            Drama,Fantasy            3.6  nm1380487
# 7               117.0          Horror,Thriller            7.3  nm0796117
# 8                80.0                    Drama            7.0  nm4197711
# 9               123.0       Action,Drama,Sport            5.4  nm8509498
# 24               85.0  Horror,Romance,Thriller            6.0  nm1491669
# ...               ...                      ...            ...        ...
# 1584            145.0    Drama,Mystery,Romance            7.2  nm1957070
# 1585            115.0             Comedy,Drama            6.1  nm0831526
# 1586             80.0  Horror,Mystery,Thriller            3.9  nm4840973
# 1593            102.0              Documentary            6.5  nm3268319
# 1605             89.0   Comedy,Horror,Thriller            4.5  nm1209639
#
#      director2 director3         director_name1 director_name2 director_name3
# 6         None      None      Deborah Kampmeier            NaN            NaN
# 7         None      None     M. Night Shyamalan            NaN            NaN
# 8         None      None  Lawrence Côté-Collins            NaN            NaN
# 9         None      None          Kook-Hee Choi            NaN            NaN
# 24        None      None              Tom Boyle            NaN            NaN
# ...        ...       ...                    ...            ...            ...
# 1584      None      None      Aishwarya Dhanush            NaN            NaN
# 1585      None      None            Pablo Stoll            NaN            NaN
# 1586      None      None              Lou Simon            NaN            NaN
# 1593      None      None         Matthew Salleh            NaN            NaN
# 1605      None      None          Marcus Dreeke            NaN            NaN
#
# [215 rows x 19 columns]

# %%
df_merge.drop_duplicates(subset = ['movie'], inplace = True)

# %%
df.assign(Book=df.Book.str.split(","))

# %%
df_split = df_merge.assign(Genre = df_merge.genres.str.split(',')).explode('Genre')

# %%
df_split.head()
# Out:
#   release_date             movie  production_budget  domestic_gross  \
# 0   2015-07-10       The Gallows           100000.0      22764410.0
# 0   2015-07-10       The Gallows           100000.0      22764410.0
# 0   2015-07-10       The Gallows           100000.0      22764410.0
# 1   2012-01-06  The Devil Inside          1000000.0      53262945.0
# 2   2011-04-01         Insidious          1500000.0      54009150.0
#
#    worldwide_gross         ROI       profit  month     tconst  start_year  \
# 0       41656474.0  415.564740   41556474.0      7  tt2309260        2015
# 0       41656474.0  415.564740   41556474.0      7  tt2309260        2015
# 0       41656474.0  415.564740   41556474.0      7  tt2309260        2015
# 1      101759490.0  100.759490  100759490.0      1  tt1560985        2012
# 2       99870886.0   65.580591   98370886.0      4  tt1591095        2010
#
#    runtime_minutes                   genres  averagerating  director1  \
# 0             81.0  Horror,Mystery,Thriller            4.2  nm4000389
# 0             81.0  Horror,Mystery,Thriller            4.2  nm4000389
# 0             81.0  Horror,Mystery,Thriller            4.2  nm4000389
# 1             83.0                   Horror            4.2  nm0068587
# 2            103.0  Horror,Mystery,Thriller            6.9  nm1490123
#
#    director2 director3      director_name1 director_name2 director_name3  \
# 0  nm3951039      None        Travis Cluff   Chris Lofing   Chris Lofing
# 0  nm3951039      None        Travis Cluff   Chris Lofing   Chris Lofing
# 0  nm3951039      None        Travis Cluff   Chris Lofing   Chris Lofing
# 1       None      None  William Brent Bell            NaN            NaN
# 2       None      None           James Wan            NaN            NaN
#
#       Genre
# 0    Horror
# 0   Mystery
# 0  Thriller
# 1    Horror
# 2    Horror

# %%
df_split
# Out:
#      release_date                  movie  production_budget  domestic_gross  \
# 0      2015-07-10            The Gallows           100000.0      22764410.0
# 1      2012-01-06       The Devil Inside          1000000.0      53262945.0
# 2      2011-04-01              Insidious          1500000.0      54009150.0
# 3      2015-04-17             Unfriended          1000000.0      32789645.0
# 4      2010-10-20  Paranormal Activity 2          3000000.0      84752907.0
# ...           ...                    ...                ...             ...
# 1603   2011-08-19          5 Days of War         12000000.0         17479.0
# 1604   2012-11-02                  Vamps         16000000.0          3361.0
# 1606   2015-01-30       Trudno byt bogom          7000000.0         31443.0
# 1607   2010-06-30             Love Ranch         25000000.0        137885.0
# 1608   2015-06-05        United Passions         30000000.0           918.0
#
#       worldwide_gross         ROI       profit  month     tconst  start_year  \
# 0          41656474.0  415.564740   41556474.0      7  tt2309260        2015
# 1         101759490.0  100.759490  100759490.0      1  tt1560985        2012
# 2          99870886.0   65.580591   98370886.0      4  tt1591095        2010
# 3          64364198.0   63.364198   63364198.0      4  tt3713166        2014
# 4         177512032.0   58.170677  174512032.0     10  tt1536044        2010
# ...               ...         ...          ...    ...        ...         ...
# 1603          87793.0   -0.992684  -11912207.0      8  tt1486193        2011
# 1604          94812.0   -0.994074  -15905188.0     11  tt1545106        2012
# 1606          41038.0   -0.994137   -6958962.0      1  tt2328813        2013
# 1607         146149.0   -0.994154  -24853851.0      6  tt1125929        2010
# 1608         168832.0   -0.994372  -29831168.0      6  tt2814362        2014
#
#       runtime_minutes                   genres  averagerating  director1  \
# 0                81.0  Horror,Mystery,Thriller            4.2  nm4000389
# 1                83.0                   Horror            4.2  nm0068587
# 2               103.0  Horror,Mystery,Thriller            6.9  nm1490123
# 3                83.0  Horror,Mystery,Thriller            5.6  nm0300174
# 4                91.0                   Horror            5.7  nm0931095
# ...               ...                      ...            ...        ...
# 1603            113.0         Action,Drama,War            5.6  nm0001317
# 1604             92.0    Comedy,Horror,Romance            5.2  nm0002132
# 1606            177.0             Drama,Sci-Fi            6.7  nm0314516
# 1607            117.0   Biography,Comedy,Drama            5.6  nm0000431
# 1608            110.0      Drama,History,Sport            2.1  nm0041474
#
#       director2 director3      director_name1 director_name2 director_name3
# 0     nm3951039      None        Travis Cluff   Chris Lofing   Chris Lofing
# 1          None      None  William Brent Bell            NaN            NaN
# 2          None      None           James Wan            NaN            NaN
# 3          None      None     Levan Gabriadze            NaN            NaN
# 4          None      None        Tod Williams            NaN            NaN
# ...         ...       ...                 ...            ...            ...
# 1603       None      None        Renny Harlin            NaN            NaN
# 1604       None      None      Amy Heckerling            NaN            NaN
# 1606       None      None      Aleksey German            NaN            NaN
# 1607       None      None     Taylor Hackford            NaN            NaN
# 1608       None      None   Frédéric Auburtin            NaN            NaN
#
# [1394 rows x 19 columns]

# %%
df_genre_test = df_split.groupby(by='Genre').count().reset_index()

# %%
df_genre_test
# Out:
#           Genre  release_date  movie  production_budget  domestic_gross  \
# 0        Action           408    408                408             408
# 1     Adventure           339    339                339             339
# 2     Animation            98     98                 98              98
# 3     Biography           129    129                129             129
# 4        Comedy           487    487                487             487
# 5         Crime           222    222                222             222
# 6   Documentary            28     28                 28              28
# 7         Drama           707    707                707             707
# 8        Family            82     82                 82              82
# 9       Fantasy           119    119                119             119
# 10      History            45     45                 45              45
# 11       Horror           153    153                153             153
# 12        Music            47     47                 47              47
# 13      Musical             6      6                  6               6
# 14      Mystery           123    123                123             123
# 15      Romance           190    190                190             190
# 16       Sci-Fi           123    123                123             123
# 17        Sport            28     28                 28              28
# 18     Thriller           237    237                237             237
# 19          War            20     20                 20              20
# 20      Western            11     11                 11              11
#
#     worldwide_gross  ROI  profit  month  tconst  start_year  runtime_minutes  \
# 0               408  408     408    408     408         408              408
# 1               339  339     339    339     339         339              339
# 2                98   98      98     98      98          98               98
# 3               129  129     129    129     129         129              129
# 4               487  487     487    487     487         487              487
# 5               222  222     222    222     222         222              222
# 6                28   28      28     28      28          28               28
# 7               707  707     707    707     707         707              707
# 8                82   82      82     82      82          82               82
# 9               119  119     119    119     119         119              119
# 10               45   45      45     45      45          45               45
# 11              153  153     153    153     153         153              153
# 12               47   47      47     47      47          47               47
# 13                6    6       6      6       6           6                6
# 14              123  123     123    123     123         123              123
# 15              190  190     190    190     190         190              190
# 16              123  123     123    123     123         123              123
# 17               28   28      28     28      28          28               28
# 18              237  237     237    237     237         237              237
# 19               20   20      20     20      20          20               20
# 20               11   11      11     11      11          11               11
#
#     genres  averagerating  director1  director2  director3  director_name1  \
# 0      408            408        408         25          2             408
# 1      339            339        339         51          9             339
# 2       98             98         98         40          9              98
# 3      129            129        129          5          0             129
# 4      487            487        487         62          9             487
# 5      222            222        222         10          1             222
# 6       28             28         28         10          3              28
# 7      707            707        707         31          1             707
# 8       82             82         82          8          0              82
# 9      119            119        119          4          0             119
# 10      45             45         45          0          0              45
# 11     153            153        153         11          0             153
# 12      47             47         47          6          0              47
# 13       6              6          6          0          0               6
# 14     123            123        123         10          1             123
# 15     190            190        190          6          0             190
# 16     123            123        123          7          0             123
# 17      28             28         28          2          0              28
# 18     237            237        237         14          0             237
# 19      20             20         20          0          0              20
# 20      11             11         11          1          0              11
#
#     director_name2  director_name3
# 0               25              25
# 1               51              51
# 2               40              40
# 3                5               5
# 4               62              62
# 5               10              10
# 6               10              10
# 7               31              31
# 8                8               8
# 9                4               4
# 10               0               0
# 11              11              11
# 12               6               6
# 13               0               0
# 14              10              10
# 15               6               6
# 16               7               7
# 17               2               2
# 18              14              14
# 19               0               0
# 20               1               1

# %%
df_genre_test.plot.bar(x='Genre', y='ROI', figsize=(10,5), fontsize=12, legend=False)
plt.title('ROI by Genre', fontsize=20)
plt.xlabel('Genre', fontsize=16)
plt.ylabel('ROI (mean)', fontsize=16)
# Out:
# Text(0, 0.5, 'ROI (mean)')

# %%
df_merge['genres'].value_counts()[:20]
# Out:
# Drama                         84
# Adventure,Animation,Comedy    68
# Comedy,Drama,Romance          57
# Comedy,Drama                  57
# Comedy                        51
# Action,Adventure,Sci-Fi       50
# Drama,Romance                 40
# Documentary                   40
# Comedy,Romance                40
# Action,Crime,Drama            37
# Action,Adventure,Fantasy      34
# Horror,Mystery,Thriller       33
# Action,Comedy,Crime           29
# Horror,Thriller               28
# Action,Adventure,Drama        27
# Drama,Thriller                26
# Biography,Drama,History       24
# Action,Crime,Thriller         23
# Action,Adventure,Comedy       22
# Crime,Drama,Thriller          22
# Name: genres, dtype: int64

# %%
df_merge.drop('director1', axis = 1, inplace = True)

# %%
df_merge.drop('director2', axis = 1, inplace = True)

# %%
df_merge.drop('director3', axis = 1, inplace = True)

# %%
df_merge.drop('tconst', axis = 1, inplace = True)

# %%
# Step 1 - split genres into genre1 and genre2. 
df_merge[['genre1', 'genre2']] = df_merge['genres'].str.split(',', n=1,  expand =True)

# %%
df_merge.head()
# Out:
#   release_date                  movie  production_budget  domestic_gross  \
# 0   2015-07-10            The Gallows           100000.0      22764410.0
# 1   2012-01-06       The Devil Inside          1000000.0      53262945.0
# 2   2011-04-01              Insidious          1500000.0      54009150.0
# 3   2015-04-17             Unfriended          1000000.0      32789645.0
# 4   2010-10-20  Paranormal Activity 2          3000000.0      84752907.0
#
#    worldwide_gross         ROI       profit  month  start_year  \
# 0       41656474.0  415.564740   41556474.0      7        2015
# 1      101759490.0  100.759490  100759490.0      1        2012
# 2       99870886.0   65.580591   98370886.0      4        2010
# 3       64364198.0   63.364198   63364198.0      4        2014
# 4      177512032.0   58.170677  174512032.0     10        2010
#
#    runtime_minutes                   genres  averagerating  \
# 0             81.0  Horror,Mystery,Thriller            4.2
# 1             83.0                   Horror            4.2
# 2            103.0  Horror,Mystery,Thriller            6.9
# 3             83.0  Horror,Mystery,Thriller            5.6
# 4             91.0                   Horror            5.7
#
#        director_name1 director_name2 director_name3  genre1            genre2
# 0        Travis Cluff   Chris Lofing   Chris Lofing  Horror  Mystery,Thriller
# 1  William Brent Bell            NaN            NaN  Horror              None
# 2           James Wan            NaN            NaN  Horror  Mystery,Thriller
# 3     Levan Gabriadze            NaN            NaN  Horror  Mystery,Thriller
# 4        Tod Williams            NaN            NaN  Horror              None

# %%
df_merge.drop('genres', axis=1, inplace=True)

# %%
import datetime
import calendar
datetime.datetime.now()

df_merge['month_name'] = df_merge['month'].apply(lambda x: calendar.month_name[x])

# %%
df_merge.head()
df_merge['month'].value_counts()
# Out:
# 9     161
# 10    156
# 11    152
# 3     148
# 12    146
# 8     138
# 4     138
# 6     130
# 7     116
# 5     109
# 1     109
# 2     106
# Name: month, dtype: int64

# %%
df_test = df_merge.groupby(by='genre1').mean()

# %%
df_test
# Out:
#              production_budget  domestic_gross  worldwide_gross        ROI  \
# genre1
# Action            8.189952e+07    8.749268e+07     2.433662e+08   2.064152
# Adventure         8.223714e+07    1.036943e+08     2.885686e+08   2.455426
# Animation         6.566667e+07    1.387641e+08     3.478513e+08   3.059936
# Biography         2.563558e+07    3.982548e+07     8.180184e+07   2.414479
# Comedy            2.384332e+07    4.022174e+07     7.423911e+07   2.731317
# Crime             2.753395e+07    3.334614e+07     7.148105e+07   1.559456
# Documentary       3.334902e+07    4.619184e+07     9.639985e+07   2.783853
# Drama             2.240145e+07    3.084828e+07     6.831769e+07   3.355847
# Family            1.600000e+08    5.040142e+08     1.259200e+09   6.869998
# Fantasy           4.732857e+07    6.830311e+07     1.862038e+08   2.188397
# Horror            1.741674e+07    4.553638e+07     9.920389e+07  15.997773
# Music             1.800000e+07    3.419967e+06     9.082906e+06  -0.495394
# Mystery           5.233333e+07    1.114222e+08     2.376665e+08   3.888130
# Romance           5.020000e+07    6.249564e+07     1.269313e+08   1.528512
# Sci-Fi            8.750000e+07    2.092609e+08     4.150633e+08   1.916977
# Sport             1.900000e+07    5.310554e+06     5.745503e+06  -0.697605
# Thriller          4.805730e+07    5.067626e+07     1.475312e+08   2.671605
#
#                    profit     month   start_year  runtime_minutes  \
# genre1
# Action       1.614667e+08  6.262443  2014.085973       113.106335
# Adventure    2.063314e+08  7.302469  2014.160494       103.104938
# Animation    2.821846e+08  8.444444  2013.333333        90.222222
# Biography    5.616626e+07  8.133333  2014.516667       115.958333
# Comedy       5.039579e+07  6.641447  2013.174342       103.447368
# Crime        4.394710e+07  7.895349  2013.546512       110.360465
# Documentary  6.305083e+07  7.509804  2014.176471        78.607843
# Drama        4.591623e+07  6.844444  2013.558730       108.339683
# Family       1.099200e+09  3.000000  2017.000000       129.000000
# Fantasy      1.388752e+08  6.142857  2013.000000       100.428571
# Horror       8.178715e+07  6.271739  2014.173913        93.956522
# Music       -8.917094e+06  9.000000  2013.000000        93.000000
# Mystery      1.853331e+08  3.666667  2010.666667       118.333333
# Romance      7.673132e+07  3.000000  2011.000000       106.000000
# Sci-Fi       3.275633e+08  4.500000  2016.500000        84.500000
# Sport       -1.325450e+07  9.000000  2014.000000       114.000000
# Thriller     9.947385e+07  7.250000  2013.666667        95.416667
#
#              averagerating
# genre1
# Action            6.360407
# Adventure         6.475926
# Animation         7.211111
# Biography         6.996667
# Comedy            6.265789
# Crime             6.466279
# Documentary       6.776471
# Drama             6.513016
# Family            7.200000
# Fantasy           5.928571
# Horror            5.565217
# Music             7.200000
# Mystery           7.500000
# Romance           7.100000
# Sci-Fi            5.550000
# Sport             7.900000
# Thriller          5.491667

# %%
df_test.reset_index(inplace=True)

# %%
fig_genre_budget, ax = plt.subplots()

plt.bar(df_test['genre1'], df_test['production_budget'])
plt.xticks(rotation = 90);

# %%
df_test.plot.scatter('genre1' , 'profit')
# Out:
# <AxesSubplot:xlabel='genre1', ylabel='profit'>

# %%
df_merge.groupby(by='month').mean().reset_index()
# Out:
#     month  production_budget  domestic_gross  worldwide_gross       ROI  \
# 0       1       3.010826e+07    4.326863e+07     1.006133e+08  6.302079
# 1       2       4.584104e+07    5.945345e+07     1.374200e+08  2.712010
# 2       3       5.666081e+07    6.893204e+07     1.663207e+08  2.243627
# 3       4       3.433047e+07    4.745915e+07     1.215392e+08  3.385687
# 4       5       7.637675e+07    8.635075e+07     2.280937e+08  2.614871
# 5       6       6.556338e+07    9.520864e+07     2.385255e+08  3.018744
# 6       7       5.970323e+07    7.912102e+07     2.117160e+08  7.393516
# 7       8       3.411464e+07    4.149854e+07     9.022094e+07  2.572879
# 8       9       2.630214e+07    3.047377e+07     6.891560e+07  2.174514
# 9      10       3.031442e+07    3.558884e+07     9.257126e+07  3.555078
# 10     11       5.785329e+07    7.303670e+07     1.955013e+08  2.681427
# 11     12       4.896507e+07    6.333153e+07     1.541506e+08  2.443017
#
#           profit   start_year  runtime_minutes  averagerating
# 0   7.050502e+07  2013.889908       105.091743       5.968807
# 1   9.157894e+07  2014.122642       106.650943       6.161321
# 2   1.096599e+08  2014.162162       104.229730       6.356757
# 3   8.720873e+07  2013.456522       104.565217       6.275362
# 4   1.517169e+08  2014.009174       108.211009       6.464220
# 5   1.729621e+08  2013.876923       106.969231       6.395385
# 6   1.520127e+08  2013.672414       106.301724       6.422414
# 7   5.610630e+07  2013.586957       103.340580       6.352174
# 8   4.261345e+07  2013.590062       104.664596       6.368944
# 9   6.225684e+07  2013.762821       107.262821       6.511538
# 10  1.376480e+08  2013.828947       110.894737       6.750658
# 11  1.051855e+08  2013.917808       113.746575       6.643836

# %%
df_merge_month = df_merge.groupby(by='month_name').mean().reset_index()
df_merge_month = df_merge_month.sort_values(by = 'month')
df_merge_month
# Out:
#    month_name  production_budget  domestic_gross  worldwide_gross       ROI  \
# 4     January       3.010826e+07    4.326863e+07     1.006133e+08  6.302079
# 3    February       4.584104e+07    5.945345e+07     1.374200e+08  2.712010
# 7       March       5.666081e+07    6.893204e+07     1.663207e+08  2.243627
# 0       April       3.433047e+07    4.745915e+07     1.215392e+08  3.385687
# 8         May       7.637675e+07    8.635075e+07     2.280937e+08  2.614871
# 6        June       6.556338e+07    9.520864e+07     2.385255e+08  3.018744
# 5        July       5.970323e+07    7.912102e+07     2.117160e+08  7.393516
# 1      August       3.411464e+07    4.149854e+07     9.022094e+07  2.572879
# 11  September       2.630214e+07    3.047377e+07     6.891560e+07  2.174514
# 10    October       3.031442e+07    3.558884e+07     9.257126e+07  3.555078
# 9    November       5.785329e+07    7.303670e+07     1.955013e+08  2.681427
# 2    December       4.896507e+07    6.333153e+07     1.541506e+08  2.443017
#
#           profit  month   start_year  runtime_minutes  averagerating
# 4   7.050502e+07    1.0  2013.889908       105.091743       5.968807
# 3   9.157894e+07    2.0  2014.122642       106.650943       6.161321
# 7   1.096599e+08    3.0  2014.162162       104.229730       6.356757
# 0   8.720873e+07    4.0  2013.456522       104.565217       6.275362
# 8   1.517169e+08    5.0  2014.009174       108.211009       6.464220
# 6   1.729621e+08    6.0  2013.876923       106.969231       6.395385
# 5   1.520127e+08    7.0  2013.672414       106.301724       6.422414
# 1   5.610630e+07    8.0  2013.586957       103.340580       6.352174
# 11  4.261345e+07    9.0  2013.590062       104.664596       6.368944
# 10  6.225684e+07   10.0  2013.762821       107.262821       6.511538
# 9   1.376480e+08   11.0  2013.828947       110.894737       6.750658
# 2   1.051855e+08   12.0  2013.917808       113.746575       6.643836

# %%
fig_month, ax = plt.subplots(figsize = (10,5))
import seaborn as sns

sns.set_style('darkgrid')
ax.bar(df_merge_month['month_name'], df_merge_month['ROI'])
plt.xticks(rotation = 90);
plt.title('Seasonality')
plt.xlabel('Release Month')
plt.ylabel('Average ROI')
plt.savefig('Images/Seasonality.png', bbox_inches = 'tight');

# %%
df_merge.head()
# Out:
#   release_date                  movie  production_budget  domestic_gross  \
# 0   2015-07-10            The Gallows           100000.0      22764410.0
# 1   2012-01-06       The Devil Inside          1000000.0      53262945.0
# 2   2011-04-01              Insidious          1500000.0      54009150.0
# 3   2015-04-17             Unfriended          1000000.0      32789645.0
# 4   2010-10-20  Paranormal Activity 2          3000000.0      84752907.0
#
#    worldwide_gross         ROI       profit  month  start_year  \
# 0       41656474.0  415.564740   41556474.0      7        2015
# 1      101759490.0  100.759490  100759490.0      1        2012
# 2       99870886.0   65.580591   98370886.0      4        2010
# 3       64364198.0   63.364198   63364198.0      4        2014
# 4      177512032.0   58.170677  174512032.0     10        2010
#
#    runtime_minutes  averagerating      director_name1 director_name2  \
# 0             81.0            4.2        Travis Cluff   Chris Lofing
# 1             83.0            4.2  William Brent Bell            NaN
# 2            103.0            6.9           James Wan            NaN
# 3             83.0            5.6     Levan Gabriadze            NaN
# 4             91.0            5.7        Tod Williams            NaN
#
#   director_name3  genre1            genre2 month_name
# 0   Chris Lofing  Horror  Mystery,Thriller       July
# 1            NaN  Horror              None    January
# 2            NaN  Horror  Mystery,Thriller      April
# 3            NaN  Horror  Mystery,Thriller      April
# 4            NaN  Horror              None    October

# %%
fig_runtime, ax = plt.subplots()
sns.set_style('darkgrid')

ax.scatter(df_merge['runtime_minutes'], df_merge['ROI'])

# %%
df_merge.sort_values(by = 'worldwide_gross', ascending = False).head(20)
# Out:
#     release_date                            movie  production_budget  \
# 213   2018-04-27           Avengers: Infinity War        300000000.0
# 188   2015-06-12                   Jurassic World        215000000.0
# 222   2012-05-04                     The Avengers        225000000.0
# 413   2015-05-01          Avengers: Age of Ultron        330600000.0
# 223   2018-02-16                    Black Panther        200000000.0
# 186   2018-06-22   Jurassic World: Fallen Kingdom        170000000.0
# 157   2013-11-22                           Frozen        150000000.0
# 156   2013-11-22                           Frozen        150000000.0
# 180   2017-03-17             Beauty and the Beast        160000000.0
# 244   2018-06-15                    Incredibles 2        200000000.0
# 344   2017-04-14          The Fate of the Furious        250000000.0
# 55    2015-07-10                          Minions         74000000.0
# 201   2018-12-21                          Aquaman        160000000.0
# 378   2016-05-06       Captain America: Civil War        250000000.0
# 264   2011-06-29   Transformers: Dark of the Moon        195000000.0
# 233   2019-03-08                   Captain Marvel        175000000.0
# 282   2012-11-08                          Skyfall        200000000.0
# 312   2014-06-27  Transformers: Age of Extinction        210000000.0
# 469   2012-07-20            The Dark Knight Rises        275000000.0
# 303   2010-06-18                      Toy Story 3        200000000.0
#
#      domestic_gross  worldwide_gross        ROI        profit  month  \
# 213     678815482.0     2.048134e+09   5.827114  1.748134e+09      4
# 188     652270625.0     1.648855e+09   6.669092  1.433855e+09      6
# 222     623279547.0     1.517936e+09   5.746382  1.292936e+09      5
# 413     459005868.0     1.403014e+09   3.243841  1.072414e+09      5
# 223     700059566.0     1.348258e+09   5.741291  1.148258e+09      2
# 186     417719760.0     1.305773e+09   6.681016  1.135773e+09      6
# 157     400738009.0     1.272470e+09   7.483133  1.122470e+09     11
# 156     400738009.0     1.272470e+09   7.483133  1.122470e+09     11
# 180     504014165.0     1.259200e+09   6.869998  1.099200e+09      3
# 244     608581744.0     1.242521e+09   5.212604  1.042521e+09      6
# 344     225764765.0     1.234846e+09   3.939385  9.848463e+08      4
# 55      336045770.0     1.160336e+09  14.680219  1.086336e+09      7
# 201     335061807.0     1.146895e+09   6.168092  9.868946e+08     12
# 378     408084349.0     1.140069e+09   3.560278  8.900694e+08      5
# 264     352390543.0     1.123791e+09   4.763028  9.287905e+08      6
# 233     426525952.0     1.123062e+09   5.417495  9.480616e+08      3
# 282     304360277.0     1.110527e+09   4.552635  9.105270e+08     11
# 312     245439076.0     1.104039e+09   4.257329  8.940391e+08      6
# 469     448139099.0     1.084439e+09   2.943415  8.094391e+08      7
# 303     415004880.0     1.068880e+09   4.344398  8.688795e+08      6
#
#      start_year  runtime_minutes  averagerating     director_name1  \
# 213        2018            149.0            8.5      Anthony Russo
# 188        2015            124.0            7.0    Colin Trevorrow
# 222        2012            143.0            8.1        Joss Whedon
# 413        2015            141.0            7.3        Joss Whedon
# 223        2018            134.0            7.3       Ryan Coogler
# 186        2018            128.0            6.2        J.A. Bayona
# 157        2013            102.0            7.5         Chris Buck
# 156        2010             93.0            6.2         Adam Green
# 180        2017            129.0            7.2        Bill Condon
# 244        2018            118.0            7.7          Brad Bird
# 344        2017            136.0            6.7       F. Gary Gray
# 55         2015             91.0            6.4      Pierre Coffin
# 201        2018            143.0            7.1          James Wan
# 378        2016            147.0            7.8      Anthony Russo
# 264        2011            154.0            6.2        Michael Bay
# 233        2019            123.0            7.0         Ryan Fleck
# 282        2012            143.0            7.8         Sam Mendes
# 312        2014            165.0            5.7        Michael Bay
# 469        2012            164.0            8.4  Christopher Nolan
# 303        2010            103.0            8.3        Lee Unkrich
#
#     director_name2 director_name3     genre1               genre2 month_name
# 213      Joe Russo      Joe Russo     Action     Adventure,Sci-Fi      April
# 188            NaN            NaN     Action     Adventure,Sci-Fi       June
# 222            NaN            NaN     Action     Adventure,Sci-Fi        May
# 413            NaN            NaN     Action     Adventure,Sci-Fi        May
# 223            NaN            NaN     Action     Adventure,Sci-Fi   February
# 186            NaN            NaN     Action     Adventure,Sci-Fi       June
# 157   Jennifer Lee   Jennifer Lee  Adventure     Animation,Comedy   November
# 156            NaN            NaN  Adventure          Drama,Sport   November
# 180            NaN            NaN     Family      Fantasy,Musical      March
# 244            NaN            NaN     Action  Adventure,Animation       June
# 344            NaN            NaN     Action       Crime,Thriller      April
# 55      Kyle Balda     Kyle Balda  Adventure     Animation,Comedy       July
# 201            NaN            NaN     Action    Adventure,Fantasy   December
# 378      Joe Russo      Joe Russo     Action     Adventure,Sci-Fi        May
# 264            NaN            NaN     Action     Adventure,Sci-Fi       June
# 233     Anna Boden     Anna Boden     Action     Adventure,Sci-Fi      March
# 282            NaN            NaN     Action   Adventure,Thriller   November
# 312            NaN            NaN     Action     Adventure,Sci-Fi       June
# 469            NaN            NaN     Action             Thriller       July
# 303            NaN            NaN  Adventure     Animation,Comedy       June

# %%
df_merge_dir = df_merge.groupby(by='director_name1').sum().reset_index()

# %%
df_merge_dir.sort_values(by = 'profit', ascending = False).head(20)
# Out:
#          director_name1  production_budget  domestic_gross  worldwide_gross  \
# 69        Anthony Russo        720000000.0    1.346647e+09     3.902606e+09
# 806       Pierre Coffin        219000000.0    9.556251e+08     2.679018e+09
# 531         Joss Whedon        555600000.0    1.082285e+09     2.920950e+09
# 184   Christopher Nolan        750000000.0    1.118801e+09     3.086180e+09
# 668         Michael Bay        648000000.0    7.778736e+08     2.911998e+09
# 793       Peter Jackson        750000000.0    8.164902e+08     2.922948e+09
# 315    Francis Lawrence        522000000.0    1.149112e+09     2.543192e+09
# 144        Bryan Singer        628000000.0    6.708550e+08     2.383073e+09
# 595         Lee Unkrich        375000000.0    6.247309e+08     1.866888e+09
# 900          Sam Mendes        500000000.0    5.044345e+08     1.990148e+09
# 1098        Zack Snyder        950000000.0    9.424978e+08     2.420920e+09
# 192     Colin Trevorrow        215750000.0    6.562816e+08     1.653277e+09
# 414           James Wan        181500000.0    5.264711e+08     1.564766e+09
# 705       Mike Mitchell        444000000.0    6.885453e+08     1.760497e+09
# 892        Ryan Coogler        237900000.0    8.259261e+08     1.539375e+09
# 977    Steven Spielberg        645000000.0    6.870743e+08     1.925340e+09
# 247         David Yates        560000000.0    5.202365e+08     1.803525e+09
# 494         Jon Favreau        345000000.0    6.764345e+08     1.584011e+09
# 846        Ridley Scott        804000000.0    6.474728e+08     2.042771e+09
# 1036        Tom McGrath        400000000.0    5.398104e+08     1.579687e+09
#
#             ROI        profit  month  start_year  runtime_minutes  \
# 69    12.589756  3.182606e+09     13        6048            432.0
# 806   33.388317  2.460018e+09     21        6038            284.0
# 531    8.990223  2.365350e+09     10        4027            284.0
# 184   12.536356  2.336180e+09     32        8053            587.0
# 668   12.924640  2.263998e+09     22        8055            602.0
# 793    8.691792  2.172948e+09     36        6039            474.0
# 315   17.030784  2.021192e+09     40       10071            666.0
# 144   20.073521  1.755073e+09     24        8061            524.0
# 595    7.904444  1.491888e+09     17        4027            208.0
# 900    6.484705  1.490148e+09     22        4027            291.0
# 1098   6.219318  1.470920e+09     32       10067            621.0
# 192   11.565516  1.437527e+09     12        4027            210.0
# 414   86.648689  1.383266e+09     23        6041            358.0
# 705   11.902989  1.316497e+09     30        8052            364.0
# 892   27.931912  1.301475e+09     20        6046            352.0
# 977   15.267844  1.280340e+09     67       14100            918.0
# 247    6.657239  1.243525e+09     29        6050            376.0
# 494    7.155887  1.239011e+09      9        4026            230.0
# 846   11.894356  1.238771e+09     59       14091            937.0
# 1036   8.714267  1.179687e+09     20        6039            285.0
#
#       averagerating
# 69             24.1
# 806            21.5
# 531            15.4
# 184            33.7
# 668            23.5
# 793            23.1
# 315            34.2
# 144            29.3
# 595            16.7
# 900            14.6
# 1098           33.2
# 192            14.0
# 414            21.5
# 705            23.2
# 892            22.4
# 977            50.6
# 247            20.2
# 494            14.4
# 846            45.9
# 1036           20.4
